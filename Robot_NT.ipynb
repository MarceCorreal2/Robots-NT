# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceCorreal2/Robots-NT/blob/main/Robot_NT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# esta es una prueba que quiero ver como se revisa en github

# %%
print("hola github")
# Out:
# hola github
